# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Assuming your CSV file is named 'your_file.csv', replace it with your actual file name
file_path = '/content/drive/My Drive/Nlp_Project/data_cleaned.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#                                               Lyrics  Dialect Artist Song  \
# 0      شدة و تزول عادي و يصير عادي بلي نطيح نعلّي...        1    NaN  NaN
# 1    بايع و شاري رابح في خطاري مركيت نهاري تعرف ا...        1    NaN  NaN
# 2   والله دنيا صعيبة زيد الناس غريبة ‎نعيشو في تر...        1    NaN  NaN
# 3       دنيا تحب الكاش كيما الانثى تحب الرانج نحك...        1    NaN  NaN
# 4    تزعز خاطري في نص الليل روحت شوار اللي بيا اس...        1    NaN  NaN
#
#       Lyrics_encoded                                     Lyrics_cleaned  \
# 0  [0 0 0 ... 0 0 0]      شدة و تزول عادي و يصير عادي بلي نطيح نعلي ...
# 1  [0 0 0 ... 0 0 0]    بايع و شاري رابح في خطاري مركيت نهاري تعرف ا...
# 2  [0 0 0 ... 0 0 0]   والله دنيا صعيبة زيد الناس غريبة نعيشو في ترك...
# 3  [0 0 0 ... 0 0 0]       دنيا تحب الكاش كيما الانثى تحب الرانج نحك...
# 4  [0 0 0 ... 0 0 0]    تزعز خاطري في نص الليل روحت شوار اللي بيا اس...
#
#   Detected_Language                                             Tokens  \
# ...

# %%
df.tail(10)
# Out:
#                                                 Lyrics  Dialect  \
# 629  Khaled\r\nRedone\r\n\n[Khaled]\r\nAna mchit wm...        2
# 630  [M Huncho]\r\nMoney's important\r\nAnd Huncho ...        2
# 631  [Paigey Cakey]\r\nThey can't fuck with us, if ...        2
# 632  Migos, Lacrim, Kore\r\n\n[Quavo]\r\nIf you get...        2
# 633  We love Africa\r\nFrom mama Africa to the worl...        0
# 634  [CKay]\r\nTu-tu-tu, uh-tu-uh-tu-tu-tu\r\nCKay,...        0
# 635  "Who taught you to hate the texture of your ha...        0
# 636  Dros in the beat, is the rhyme of the street\r...        0
# 637  [Obie Trice]\r\nAyo LBandy on The Mack\r\n\n[T...        0
# 638  Achekam achekam, chekem ura dayi, \r\nAkhmi gh...        0
#
#               Artist                                Song     Lyrics_encoded  \
# 629              NaN                                 NaN  [0 0 0 ... 0 0 0]
# 630              NaN                                 NaN  [0 0 0 ... 0 0 0]
# ...

# %%
df.head(10)
# Out:
#                                               Lyrics  Dialect Artist Song  \
# 0      شدة و تزول عادي و يصير عادي بلي نطيح نعلّي...        1    NaN  NaN
# 1    بايع و شاري رابح في خطاري مركيت نهاري تعرف ا...        1    NaN  NaN
# 2   والله دنيا صعيبة زيد الناس غريبة ‎نعيشو في تر...        1    NaN  NaN
# 3       دنيا تحب الكاش كيما الانثى تحب الرانج نحك...        1    NaN  NaN
# 4    تزعز خاطري في نص الليل روحت شوار اللي بيا اس...        1    NaN  NaN
# 5     Why you acting so cold حكييت بلي حكيت اما ا...        1    NaN  NaN
# 6     دنيا مبعدك ماتسواش برشا كلام ما تحكاش  دنيا...        1    NaN  NaN
# 7    "في سماية غيمة و ليلي و القمرة ما ريت شبي عي...        1    NaN  NaN
# 8     كي نشوف اللي صار نعرف اللي كلو مني كيف نشوط...        1    NaN  NaN
# 9   كحلة و بيضة كالبيانو حياتي كيما الميلودى يااه...        1    NaN  NaN
#
#       Lyrics_encoded                                     Lyrics_cleaned  \
# 0  [0 0 0 ... 0 0 0]      شدة و تزول عادي و يصير عادي بلي نطيح نعلي ...
# ...

# %%
# !pip install transformers

# %%
# Use value_counts to get the counts of each unique value in 'Dialect'
dialect_counts = df['Dialect'].value_counts()

# Print the statistics
print("Dialect Statistics:")
print(dialect_counts)
# Out:
# Dialect Statistics:
# 2    367
# 0    176
# 1     96
# Name: Dialect, dtype: int64

# %%
# Install required libraries
# pip install torch transformers

import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
import pandas as pd
import os
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Assuming you have a dataset with lyrics and labels
# Adjust the paths and file extensions based on your dataset

data_path = "/content/drive/My Drive/Nlp_Project/data_cleaned.csv"  # CSV file with 'lyrics' and 'label' columns
df = pd.read_csv(data_path)

# Split the dataset into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Define a custom dataset class
class LyricsDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.dataframe = dataframe
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        lyrics = " ".join(self.dataframe.iloc[idx]["Lyrics_cleaned"].split())  # Assuming 'lyrics' is the column with lyrics
        encoding = self.tokenizer(
            lyrics,
            return_tensors="pt",
            max_length=self.max_length,
            truncation=True,
            padding="max_length",
        )
        return {
            "input_ids": encoding["input_ids"].flatten(),
            "attention_mask": encoding["attention_mask"].flatten(),
            "label": torch.tensor(label_encoder.transform([self.dataframe.iloc[idx]["Dialect"]])[0]),
        }
'''
# Initialize the BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=3)
'''

tokenizer = AutoTokenizer.from_pretrained("CAMeL-Lab/bert-base-arabic-camelbert-mix-did-madar-corpus26")
model = AutoModelForSequenceClassification.from_pretrained("CAMeL-Lab/bert-base-arabic-camelbert-mix-did-madar-corpus26")

# Initialize a label encoder to convert labels to numerical format
label_encoder = LabelEncoder()
label_encoder.fit(df["Dialect"])

# Create datasets and dataloaders
train_dataset = LyricsDataset(train_df, tokenizer)
test_dataset = LyricsDataset(test_df, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# Define training parameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
criterion = torch.nn.CrossEntropyLoss()

# Training loop
num_epochs = 50
for epoch in range(num_epochs):
    model.train()
    for batch in tqdm(train_loader, desc="Epoch {}".format(epoch + 1)):
        inputs = {k: v.to(device) for k, v in batch.items() if k != "label"}
        labels = batch["label"].to(device)

        optimizer.zero_grad()
        outputs = model(**inputs)
        loss = criterion(outputs.logits, labels)
        loss.backward()
        optimizer.step()

# Evaluation loop
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        inputs = {k: v.to(device) for k, v in batch.items() if k != "label"}
        labels = batch["label"].to(device)

        outputs = model(**inputs)
        _, predicted = torch.max(outputs.logits, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = correct / total
print("Test Accuracy: {:.2%}".format(accuracy))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/305k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# ...
# Evaluating: 100%|██████████| 32/32 [00:04<00:00,  6.54it/s]
# Test Accuracy: 91.41%

# %%
# Save the model weights
model_save_path = "/content/drive/My Drive/Nlp_Project/model_weights.pth"
torch.save(model.state_dict(), model_save_path)

# %%
# Save the tokenizer
tokenizer_save_path = "/content/drive/My Drive/Nlp_Project/tokenizer"
tokenizer.save_pretrained(tokenizer_save_path)
# Out:
# ('/content/drive/My Drive/Nlp_Project/tokenizer/tokenizer_config.json',
#  '/content/drive/My Drive/Nlp_Project/tokenizer/special_tokens_map.json',
#  '/content/drive/My Drive/Nlp_Project/tokenizer/vocab.txt',
#  '/content/drive/My Drive/Nlp_Project/tokenizer/added_tokens.json',
#  '/content/drive/My Drive/Nlp_Project/tokenizer/tokenizer.json')

# %%
# Load the saved model weights
loaded_model = AutoModelForSequenceClassification.from_pretrained("CAMeL-Lab/bert-base-arabic-camelbert-mix-did-madar-corpus26")
loaded_model.load_state_dict(torch.load(model_save_path))
loaded_model.eval()
loaded_model.to(device)  # Move the model to the correct device

# Load the saved tokenizer
loaded_tokenizer = AutoTokenizer.from_pretrained(tokenizer_save_path)

# Use the loaded model and tokenizer for classification
lyrics_to_classify ="O Abdelkader ya Bouaalam daq el'hal aaliya و عبدالقادر يا بو علم ضاق الحال عليّ Dawi hali ya Bouaalam, sidi rouf aaliya داوي حالي يا بو علم سيدي ارؤف عليّ O Abdelkader ya Bouaalam daq el'hal aaliya عبدالقادر يا بو علم ضاق الحال عليّ"
#"إنت معلم وإحنا منك نتعلم إنت معلم وإحنا منك نتعلم نسكت وإنت موجود ما نرضى نتكلم نسكت وإنت موجود ما نرضى نتكلم إنت معلم وإحنا منك نتعلم إنت معلم وإحنا منك نتعلم آه نسكت وإنت موجود ما نرضى نتكلم نسكت وإنت موجود ما نرضى نتكلم"
#"Why you acting so cold حكييت بلي حكيت اما انت مافهمتنيش اما هاي الرقية so good مشيت هاك مشيت انا بالش بيك نعيش Baby نحب نوليrich كيما rodireich لضلموني لا منسيتش انا لا منسيتش جات الكورة مارتيتش كيما راكيتيتش قلبي معبي ب1000 speach اما لا محكيتش Baby نحب نولي star ونفرح الدار نحب الحومة ملي صغار و نشرف الجار شاقي و ماشي فوق النار خير من اللي بطال ايجا نقلك عالغنار شارع فيه ابطال  طاير بلاشي ريش كيما ابراهيموفيتش شكاير و تمهميش لين عينيك النور ما تريش لاموني كيفاش نعيش حسدوني كيفاش نعيش ماتنساش و ماتنسيش عندي يجي كان اللي ميجيش شكون اللي قال بلابيك الشمس تغيب شكون اللي قال و قتلي نمشي يعني مني العيب الاحلام افعال واللي يعطل ميوليش حبيب لكلام اللي تقال كيتعاود معندو مايجيب ممكن اليوم ولينا نعيشو غير من بارح مش كل البارح و لا اكبر اليوم من داخل كلدي يحسوني كنبدا سارح تعلمت نعيش الفرحة كان كنصبر عالهموم  Why you acting so cold حكييت بلي حكيت اما انت مافهمتنيش اما هاي الرقية so good مشيت هاك مشيت انا بالش بيك نعيش Baby نحب نوليrich كيما rodireich لضلموني لا منسيتش انا لا منسيتش جات الكورة مارتيتش كيما راكيتيتش قلبي معبي ب1000 speach اما لا محكيتش Baby نحب نولي star ونشرف الدار نحب الحومة ملي صغار و نفرح الجار شاقي و ماشي فوق النار خير من اللي بطال ايجا نقلك عالغنار شارع فيه ابطال  مافهمتنيش قتلك غدوة قتلي مايهمنيش ماسمعتنيش تحب نراك توا لا منجيش ماقناعتنيش مانفاعتنيش ماللول ميجيش مش وقت طيش حاب نعيش مشيت عرفت نعيش امي فرحانة نمد مصروف ولدي معروف في كل لسان قلمو علم للي مد كفوف نحكي خدمة خاطر خطي ماعادش كيوف كل سطر يوصي قلبي بش يكره الخوف خلط برشا خلاط لحبوني لحبوني خذاو يخاطري مشات الناس لحلفة باش تبقى عمرها ما بقاتلي why i'm acting so cold الشيخة عطاتني كنويت بش نعطت باز الخطة عندي عطتني  Why you acting so cold حكييت بلي حكيت اما انت مافهمتنيش اما هاي الرقية so good مشيت هاك مشيت انا بالش بيك نعيش Baby نحب نوليrich كيما rodireich لضلموني لا منسيتش انا لا منسيتش جات الكورة مارتيتش كيما راكيتيتش قلبي معبي ب1000 speach اما لا محكيتش Baby نحب نولي star ونفرح الدار نحب الحومة ملي صغار و نشرف الجار شاقي و ماشي فوق النار خير من اللي بطال ايجا نقلك عالغنار شارع فيه ابطال"
#"Sa7bek khouk 7bibek, 7bibek howa jibek 3ndak dirou 9ribek, a sa7bi A 3i9 w fi9 men l galba, hada zman el 7ebba Rah lwe9t s3ab w fin s7ab, a sa7bi Sa7bek khouk 7bibek, 7bibek howa jibek 3ndak dirou 9ribek, a sa7bi A 3i9 w fi9 men l galba, hada zman el 7ebba Rah lwe9t s3ab w fin s7ab, a sa7bi"
input_encoding = loaded_tokenizer(lyrics_to_classify, return_tensors="pt", max_length=512, truncation=True, padding="max_length")
input_encoding = {k: v.to(device) for k, v in input_encoding.items()}  # Move input to the correct device
output = loaded_model(**input_encoding)
predicted_label = torch.argmax(output.logits).item()

# Convert back to the original label using the label encoder
predicted_label_str = label_encoder.inverse_transform([predicted_label])[0]

print("Predicted Dialect:", predicted_label_str)
# Out:
# Predicted Dialect: 0

# %%
# ... (Your existing code)

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Evaluation loop
model.eval()
all_predicted_labels = []
all_true_labels = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        inputs = {k: v.to(device) for k, v in batch.items() if k != "label"}
        labels = batch["label"].to(device)

        outputs = model(**inputs)
        _, predicted = torch.max(outputs.logits, 1)

        all_predicted_labels.extend(predicted.cpu().numpy())
        all_true_labels.extend(labels.cpu().numpy())

# Convert the predicted and true labels to numpy arrays
predicted_labels = np.array(all_predicted_labels)
true_labels = np.array(all_true_labels)

# Create a confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# Evaluating: 100%|██████████| 32/32 [00:04<00:00,  6.66it/s]
