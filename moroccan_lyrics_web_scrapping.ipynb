# %%
import requests
from bs4 import BeautifulSoup
import csv

urls = [
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ana-machi-sahel.html'
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-taj.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-nta.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-morak.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-7iya.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-tu-m-aimes.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-makhelaw-magalou.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-9ad-bia.html',
    'https://paroles2chansons.lemonde.fr/paroles-manal/paroles-slay.html' ,
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-laayoun-aainiya.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-ana-maghrabi.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-douni-labladi.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-lalla-maryama.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-lyam-zina.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-hasdou.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-klam-ennas.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-latgoulich-nsani.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-chouf-chouf.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-habibi.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-dar-el-alia.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-mustahil.html',
    'https://paroles2chansons.lemonde.fr/paroles-douzi/paroles-mina.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-ya-saken.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-bla-3onwane-l-rrrr-rrrr-rrr-rrrrr.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-akher-marra-l-rrrr-rrrr-rrr-rrr.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-ba3et-elhob.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-aalach-ya-lil.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-albak-yemchi-lhalo.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-wabba.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-ba9i.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-hasdouna.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-khater.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-matbedeltch.html',
    'https://paroles2chansons.lemonde.fr/paroles-hatim-ammor/paroles-al-awal.html',
    'https://paroles2chansons.lemonde.fr/paroles-amine-aminux/paroles-makayen-ma.html',
    'https://paroles2chansons.lemonde.fr/paroles-amine-aminux/paroles-cendrillon.html',
    'https://paroles2chansons.lemonde.fr/paroles-amine-aminux/paroles-tingisha.html',
    'https://paroles2chansons.lemonde.fr/paroles-amine-aminux/paroles-we-love-africa.html',
    'https://paroles2chansons.lemonde.fr/paroles-fnaire/paroles-asif-habibi.html',
    'https://paroles2chansons.lemonde.fr/paroles-fnaire/paroles-dilbar-arabic-version.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-ya-denia.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-issawa-style.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-h-k-kima-dima.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-titiz.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-h-bik.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-tfe-dow-rrr-rrrr.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-f-mo-hadak.html'
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-m-tenga.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-sahbi.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-f-l-houma.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-h-kayne.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-sh-hal-how-how.html',
    'https://paroles2chansons.lemonde.fr/paroles-h-kayne/paroles-gana.html',
    'https://paroles2chansons.lemonde.fr/paroles-omar-belmir/paroles-lghorbal.html',
    'https://paroles2chansons.lemonde.fr/paroles-jamila/paroles-blach-blach.html',
    'https://paroles2chansons.lemonde.fr/paroles-jamila/paroles-damdouma.html',
    'https://paroles2chansons.lemonde.fr/paroles-jamila/paroles-yegoulo-yegoulo.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-guli-mata.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-lewjah-tani.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-enty.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ensay.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-adda-elkalam.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-lemen-nechki.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ya-ayouni.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-wana-maak.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-lghadi-wehdou.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-mal-hbibi-malou.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-enty-hayaty.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-lemima.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-el-hala.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-casablanca.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ma-ahla-lmakan.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-salam.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-lamaallem.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ghaltana.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ala-babi-waef-amarin.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-yalla-yalla.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-ykhalik-lili.html',
    'https://paroles2chansons.lemonde.fr/paroles-saad-lamjarred/paroles-rrrrr-rrrrrr-rrr.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-pardon.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-kif-kif.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-kossori.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-tmax.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-chicha.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-mahmouma.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-allo-a.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-damiri.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-jmi.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-c-est-la-vie.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-la-trace.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-sbabo-nti.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-ghdara.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-zakaria.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-galaxy.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-allo-baba.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles-kata.html',
    'https://paroles2chansons.lemonde.fr/paroles-lbenj/paroles
html',
    'https://paroles2chansons.lemonde.fr/paroles-zouhir-bahaoui/paroles-ghamza.html',
    'https://paroles2chansons.lemonde.fr/paroles-zouhir-bahaoui/paroles-muchas-gracias.html',
    'https://paroles2chansons.lemonde.fr/paroles-cravata/paroles-ghbrti-3liya.html',
    'https://paroles2chansons.lemonde.fr/paroles-cravata/paroles-habibi-sayd-l9adi.html',
    'https://paroles2chansons.lemonde.fr/paroles-cravata/paroles-celibataire.html',
    'https://paroles2chansons.lemonde.fr/paroles-cravata/paroles-smahli.html',
    'https://paroles2chansons.lemonde.fr/paroles-cravata/paroles-3ayat.html',
    'https://paroles2chansons.lemonde.fr/paroles-cravata/paroles-khwit-menou-rassi.html',
    'https://paroles2chansons.lemonde.fr/paroles-salma-rachid/paroles-ma-gazelle-rrrrrrr.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-falastini-remix.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-gouli-je-t-aime.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-deconnectes.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-n-brik-n-brik.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-toute-ma-vie.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-frontieres.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-desole-por-favor.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-zinaoua-ft-leck-leila-chakir.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-zinaoua-ft-leck-leila-chakir.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-j-me-sers-un-re-ve.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-marocaines.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-chekama.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-berbere-gang.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-dayni-daini.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-mamino-ft-ali-b-hafssa-da.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-la-cabeza-ft-imen-es-nassi.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-mehlia-c-est-fini.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-hadi-ma-vie.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-c-est-une-frappe.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-wesh-hada.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-diamant.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-officiel.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-titiza.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-latino-gang.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-ma-cherie-ft-leck.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-msayfa.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-pina-colada.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-karima.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-dima-nachat-sur-snapchat.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-miss-vilaine.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-t-mon-bb-ft-abdi-mounir-kidadi.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-walou-walou.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-yal-bnete.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-yal-meknessi.html',
    'https://paroles2chansons.lemonde.fr/paroles-dj-hamida/paroles-yemma.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-nebghi-djini-bsurvet.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-labsa-jelaba.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-hayat.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-krite-l-message.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-ma-nedikch-a-l-vacancia.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-a-toz.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-lay-lay.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-elle-me-rend-dingue.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-ven-aqui.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-loquito-de-amor.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-la-beaute.html',
    'https://paroles2chansons.lemonde.fr/paroles-aymane-serhani/paroles-dayrine-dajja.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-hes-biya.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-ma-denbi.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-ya-omri.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-inti7ar.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-lghrib.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-khaliwni.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-kan-mektab.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-ya-nas.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-mahma-kan.html',
    'https://paroles2chansons.lemonde.fr/paroles-l7or/paroles-melit.html'
        ]

lyrics_data = []

for url in urls:
    link = requests.get(url)
    soup = BeautifulSoup(link.text, 'lxml')

    # Use a more specific selector for lyrics
    lyrics = soup.find('div', {'class': 'border block-spacing-medium text-center'})

    # Extracting artist and song names from the URL
    url_parts = url.split('/')
    artist_name = url_parts[-2].replace('-',' ').replace('paroles','')
    song_name = url_parts[-1].replace('-',' ').replace('.html','').replace('paroles','')

    if lyrics:

        # Extract and clean the lyrics
        lyrics_text = lyrics.text.strip()

        if 'Traduction' in lyrics_text:
            stopping_point = 'Traduction'
        else:
            stopping_point = 'Paroles2Chansons'

        lyrics_text = lyrics_text[0:lyrics_text.find(stopping_point)]

        lyrics_data.append({'Artist': artist_name, 'Song': song_name, 'Lyrics': lyrics_text, 'Dialect': 0})

# Save the data to a CSV file
with open('moroccan_song_lyrics.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['
          'https://marocsite.net/كلمات-اغنية-العار-يا-العار/',
          'https://marocsite.net/كلمات-اغنية-جونيمار/',
          'https://marocsite.net/كلمات-ايناس-ايناس-بلامازيغية/',
          'https://marocsite.net/كلمات-الحبيب-الحبيب/',
          'https://marocsite.net/كلمات-مولاي-عبد-بصيغة-خدوج-السطاتية/',
          'https://marocsite.net/كلمات-مولاي-عبد-الله-بصيغة-حجيب/',
          'https://marocsite.net/كلمات-الزين-ولاطاي-كلشي-كاين/',
          'https://marocsite.net/كلمات-سيدي-حبيبي-فين-هو/',
          'https://marocsite.net/كلمات-جيل-جيلالة-الا-ضاق-الحال/',
          'https://marocsite.net/كلمات-اش-داك-تمشي-للزين/',
          'https://marocsite.net/كلمات-يا-من-ملكني-عبدا/',
          'https://marocsite.net/كلمات-السانية-والبير/',
          'https://marocsite.net/نساني-نساني-حجيب-كلمات/',
          'https://marocsite.net/يا-محبوبي-كلمات/',
          'https://marocsite.net/كتبت-ليك-برية-كلمات/',
          'https://marocsite.net/شوفي-غيرو-كلمات/',
          'https://marocsite.net/هلا-هلا-المغاربة-سبوعة-ورجالة-مكتوبة/',
          'https://marocsite.net/الزميتة-كلمات/',
          'https://marocsite.net/ارحمني-من-عينيك-كلمات/',
          'https://marocsite.net/لالة-فاطمة-كلمات/',
          'https://marocsite.net/واه-داك-الغافل-كلمات/',
          'https://marocsite.net/سالبة-سالبة-كلمات/',
          'https://marocsite.net/رجال-الله-كلمات/',
          'https://marocsite.net/ركبت-على-عين-زورة-كلمات/'
]

for url in urls_2:
    link = requests.get(url)
    soup = BeautifulSoup(link.text, 'lxml')

    # Use a more specific selector for lyrics
    lyrics = soup.find('div', {'class': 'content'})

    # Extracting artist and song names
    # Find the rows of the table

    table = soup.find('table')

    if table:
        table_rows = table.find_all('tr')

        # Extract song name and artist name if the structure is as expected
        # Check if there are enough rows
        if len(table_rows) > 1:
            # Check if there are enough cells in the first row
            cells_row_0 = table_rows[0].find_all('td')
            if len(cells_row_0) > 1:
                song_cell = cells_row_0[1].strong
                # Check if there are enough cells in the second row
                cells_row_1 = table_rows[1].find_all('td')
                if len(cells_row_1) > 1:
                    artist_cell = cells_row_1[1].strong

                    if song_cell and artist_cell:
                        song_name2 = song_cell.text.strip()
                        artist_name2 = artist_cell.text.strip()

                        if lyrics :

                            # Extract and clean the lyrics
                            lyrics_text = lyrics.text.strip()
                          # Exclude the first line
                            first_newline_index = lyrics_text.find('\n')
                            if first_newline_index != -1:
                                lyrics_text = lyrics_text[first_newline_index + 1:].strip()

                            index = lyrics_text.find('العنوان')
                            if index != -1:
                                lyrics_text = lyrics_text[:index].strip()
                            lyrics_data.append({'Artist': artist_name2, 'Song': song_name2, 'Lyrics': lyrics_text, 'Dialect': 0})


# Save the data to a CSV file
with open('moroccan_song_lyrics.csv', 'a', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    for data in lyrics_data:
        writer.writerow(data)
